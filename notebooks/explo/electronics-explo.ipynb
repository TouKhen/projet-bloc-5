# %%
from src.data import load_file

df = load_file('../../data/raw/Electronics.jsonl/Electronics.jsonl');

# %%
df.head()
# Out:
#    rating              title  \
# 0       5         Work great
# 1       5  excellent product
# 2       5    Happy customer!
# 3       5      Amazing value
# 4       5        Dryer parts
#
#                                                 text images        asin  \
# 0              work great. use a new one every month     []  B01N0TQ0OH
# 1                            Little on the thin side     []  B07DD2DMXB
# 2                   Quick delivery, fixed the issue!     []  B082W3Z9YK
# 3  I wasn't sure whether these were worth it or n...     []  B078W2BJY8
# 4  Easy to install got the product expected to re...     []  B08C9LPCQV
#
#   parent_asin                       user_id               timestamp  \
# 0  B01N0TQ0OH  AGKHLEW2SOWHNMFQIJGBECAF7INQ 2018-02-22 16:31:48.692
# 1  B07DD37QPZ  AHWWLSPCJMALVHDDVSUGICL6RUCA 2022-10-02 21:41:03.446
# 2  B082W3Z9YK  AHZIJGKEWRTAEOZ673G5B3SNXEGQ 2020-12-06 03:30:35.363
# 3  B078W2BJY8  AFGUPTDFAWOHHL4LZDV27ERDNOYQ 2018-08-12 20:03:04.306
# ...

# %% [markdown]
# ### Inspect the shape and columns

# %%
print(df.shape)
print(list(df.columns))
# Out:
# (2128605, 10)
# ['rating', 'title', 'text', 'images', 'asin', 'parent_asin', 'user_id', 'timestamp', 'helpful_vote', 'verified_purchase']

# %% [markdown]
# ### Check basic info and types

# %%
print(df.info())
print(df.dtypes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2128605 entries, 0 to 2128604
# Data columns (total 10 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   rating             int64
#  1   title              object
#  2   text               object
#  3   images             object
#  4   asin               object
#  5   parent_asin        object
#  6   user_id            object
#  7   timestamp          datetime64[ns]
#  8   helpful_vote       int64
#  9   verified_purchase  bool
# dtypes: bool(1), datetime64[ns](1), int64(2), object(6)
# memory usage: 148.2+ MB
# None
# rating                        int64
# title                        object
# text                         object
# images                       object
# asin                         object
# parent_asin                  object
# user_id                      object
# timestamp            datetime64[ns]
# helpful_vote                  int64
# verified_purchase              bool
# ...

# %% [markdown]
# ### Peek at the data

# %%
df.sample(n=5)
# Out:
#          rating                                              title  \
# 807999        5      Perfect size for the mini 4 cup coffee makers
# 1923257       5                               Fix your noisy dryer
# 857887        2  Don’t plan on positioning under upper kitchen ...
# 1332088       5                                     Fits oven well
# 1681704       5                                         Five Stars
#
#                                                       text images        asin  \
# 807999   Perfect size for the mini 4 cup coffee makers....     []  B000FKHLLQ
# 1923257  DYI dryer repair! Went well with this part and...     []  B07YNGGT3N
# 857887   This is called a “countertop” dishwasher. I do...     []  B07VR22832
# 1332088  Fit into oven glad you can still get obscure i...     []  B082KKJQPV
# 1681704              Fit's and works great in my Keurig V2     []  B008O7Z1F0
#
#         parent_asin                       user_id               timestamp  \
# ...

# %% [markdown]
# ### Summary statistics

# %%
df.describe()
# Out:
#              rating                      timestamp  helpful_vote
# count  2.128605e+06                        2128605  2.128605e+06
# mean   4.221502e+00  2019-07-02 04:30:50.198397184  9.288868e-01
# min    1.000000e+00            2000-10-23 14:37:23  0.000000e+00
# 25%    4.000000e+00     2017-08-07 16:55:36.596000  0.000000e+00
# 50%    5.000000e+00  2020-01-14 02:05:18.801999872  0.000000e+00
# 75%    5.000000e+00  2021-08-15 14:28:44.068999936  0.000000e+00
# max    5.000000e+00     2023-09-12 16:29:17.016000  5.704000e+03
# std    1.380826e+00                            NaN  1.252679e+01

# %% [markdown]
# ### Missing values

# %%
df.isna().sum()
# Out:
# rating               0
# title                0
# text                 0
# images               0
# asin                 0
# parent_asin          0
# user_id              0
# timestamp            0
# helpful_vote         0
# verified_purchase    0
# dtype: int64

# %% [markdown]
# ### Distribution and unique values

# %%
df['rating'].value_counts(dropna=False)
# Out:
# rating
# 5    1486225
# 1     250453
# 4     208216
# 3     104047
# 2      79664
# Name: count, dtype: int64

# %%
df['helpful_vote'].value_counts(dropna=False)
# Out:
# helpful_vote
# 0       1719985
# 1        214485
# 2         67897
# 3         33099
# 4         19303
#          ...
# 246           1
# 254           1
# 406           1
# 384           1
# 1545          1
# Name: count, Length: 533, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(df['rating'])
# Out:
# <Axes: xlabel='rating', ylabel='Count'>
