# %%
from src.data import load_file

df = load_file('../../data/raw/Industrial_and_Scientific.jsonl/Industrial_and_Scientific.jsonl');

# %%
df.head()
# Out:
#    rating                         title  \
# 0       5      Best value for the money
# 1       5                     TOO good.
# 2       4                          Good
# 3       5                    Five Stars
# 4       1  Only one ply - will not work
#
#                                                 text images        asin  \
# 0  These masks are great even though there is no ...     []  B08C7HDF1F
# 1  These scissors are so good they got stolen by ...     []  B07BT4YLHT
# 2  Good. Sensor push easier to work with but thes...     []  B06XY65HCX
# 3  Great ORB finish & size. Bought for our laundr...     []  B01KW20EQ0
# 4  These masks are notably thinner than other dis...     []  B08F59NF33
#
#   parent_asin                       user_id               timestamp  \
# 0  B0BX2672L8  AG2L7H23R5LLKDKLBEF2Q3L2MVDA 2023-02-17 02:54:13.163
# 1  B07BT4YLHT  AG2L7H23R5LLKDKLBEF2Q3L2MVDA 2022-12-24 01:09:30.434
# 2  B06XY65HCX  AGCI7FAH4GL5FI65HYLKWTMFZ2CQ 2020-01-21 19:54:56.378
# ...

# %% [markdown]
# ### Inspect the shape and columns

# %%
print(df.shape)
print(list(df.columns))
# Out:
# (5183005, 10)
# ['rating', 'title', 'text', 'images', 'asin', 'parent_asin', 'user_id', 'timestamp', 'helpful_vote', 'verified_purchase']

# %% [markdown]
# ### Check basic info and types

# %%
print(df.info())
print(df.dtypes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5183005 entries, 0 to 5183004
# Data columns (total 10 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   rating             int64
#  1   title              object
#  2   text               object
#  3   images             object
#  4   asin               object
#  5   parent_asin        object
#  6   user_id            object
#  7   timestamp          datetime64[ns]
#  8   helpful_vote       int64
#  9   verified_purchase  bool
# dtypes: bool(1), datetime64[ns](1), int64(2), object(6)
# memory usage: 360.8+ MB
# None
# rating                        int64
# title                        object
# text                         object
# images                       object
# asin                         object
# parent_asin                  object
# user_id                      object
# timestamp            datetime64[ns]
# helpful_vote                  int64
# verified_purchase              bool
# ...

# %% [markdown]
# ### Peek at the data

# %%
df.sample(n=5)
# Out:
#          rating                                              title  \
# 333448        5                                         Five Stars
# 3320206       5                                         Five Stars
# 2922583       5  and they were so happy, as the assorment worke...
# 4702173       5                                      Quality Boxes
# 4445104       5                                                 ..
#
#                                                       text  \
# 333448                                    Works very well!
# 3320206                                    Works Great!!!!
# 2922583  Bought this as a gift for folks that bought a ...
# 4702173  These were really nice boxes for the price.  W...
# 4445104  [[VIDEOID:330bfbaaa24479208c134b990ae0e7f5]] I...
#
#                                                     images        asin  \
# 333448                                                  []  B009GJBM8A
# ...

# %% [markdown]
# ### Summary statistics

# %%
df.describe()
# Out:
#              rating                      timestamp  helpful_vote
# count  5.183005e+06                        5183005  5.183005e+06
# mean   4.183227e+00  2019-08-05 09:51:58.237731584  9.320352e-01
# min    1.000000e+00            1998-04-26 06:56:55 -1.000000e+00
# 25%    4.000000e+00  2017-09-28 20:24:53.438000128  0.000000e+00
# 50%    5.000000e+00  2020-02-03 00:30:04.969999872  0.000000e+00
# 75%    5.000000e+00  2021-09-03 23:11:48.819000064  0.000000e+00
# max    5.000000e+00     2023-09-12 17:40:25.306000  5.611000e+03
# std    1.376844e+00                            NaN  9.970753e+00

# %% [markdown]
# ### Missing values

# %%
df.isna().sum()
# Out:
# rating               0
# title                0
# text                 0
# images               0
# asin                 0
# parent_asin          0
# user_id              0
# timestamp            0
# helpful_vote         0
# verified_purchase    0
# dtype: int64

# %% [markdown]
# ### Distribution and unique values

# %%
df['rating'].value_counts(dropna=False)
# Out:
# rating
# 5    3487385
# 1     584133
# 4     560932
# 3     315792
# 2     234763
# Name: count, dtype: int64

# %%
df['helpful_vote'].value_counts(dropna=False)
# Out:
# helpful_vote
# 0       3991975
# 1        636007
# 2        210837
# 3        100744
# 4         57508
#          ...
# 450           1
# 677           1
# 332           1
# 512           1
# 1076          1
# Name: count, Length: 684, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(df['rating'])
# Out:
# <Axes: xlabel='rating', ylabel='Count'>
