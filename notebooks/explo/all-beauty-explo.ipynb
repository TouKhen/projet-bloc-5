# %%
from src.data import load_file

items_df = load_file('../../data/raw/meta_All_Beauty.jsonl/meta_All_Beauty.jsonl');
reviews_df = load_file('../../data/raw/All_Beauty.jsonl/All_Beauty.jsonl');

# %%
items_df.head()
# Out:
#   main_category                                              title  \
# 0    All Beauty  Howard LC0008 Leather Conditioner, 8-Ounce (4-...
# 1    All Beauty  Yes to Tomatoes Detoxifying Charcoal Cleanser ...
# 2    All Beauty   Eye Patch Black Adult with Tie Band (6 Per Pack)
# 3    All Beauty  Tattoo Eyebrow Stickers, Waterproof Eyebrow, 4...
# 4    All Beauty  Precision Plunger Bars for Cartridge Grips – 9...
#
#    average_rating  rating_number  \
# 0             4.8             10
# 1             4.5              3
# 2             4.4             26
# 3             3.1            102
# 4             4.3              7
#
#                                             features  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [Material: 304 Stainless Steel; Brass tip, Len...
#
# ...

# %%
reviews_df.head()
# Out:
#    rating                                      title  \
# 0       5  Such a lovely scent but not overpowering.
# 1       4     Works great but smells a little weird.
# 2       5                                       Yes!
# 3       1                          Synthetic feeling
# 4       5                                         A+
#
#                                                 text images        asin  \
# 0  This spray is really nice. It smells really go...     []  B00YQ6X8EO
# 1  This product does what I need it to do, I just...     []  B081TJ8YS3
# 2                          Smells good, feels great!     []  B07PNNCSP9
# 3                                     Felt synthetic     []  B09JS339BZ
# 4                                            Love it     []  B08BZ63GMJ
#
#   parent_asin                       user_id               timestamp  \
# 0  B00YQ6X8EO  AGKHLEW2SOWHNMFQIJGBECAF7INQ 2020-05-05 14:08:48.923
# 1  B081TJ8YS3  AGKHLEW2SOWHNMFQIJGBECAF7INQ 2020-05-04 18:10:55.070
# ...

# %%
items_df[items_df['parent_asin'] == 'B097R46CSY']
# Out:
#       main_category                                              title  \
# 15700    All Beauty  New Road Beauty - Creamsicle - Variety 3 Pack ...
#
#        average_rating  rating_number  \
# 15700             4.4            699
#
#                                                 features  \
# 15700  [Same Great Product, NEW PACKAGING., MOISTURIZ...
#
#                                              description  price  \
# 15700  [New Road Beauty Paraffin Wax is recommended f...  21.98
#
#                                                   images  \
# 15700  [{'thumb': 'https://m.media-amazon.com/images/...
#
#                                                   videos            store  \
# 15700  [{'title': 'Opening the Creamsicle assortment ...  New Road Beauty
#
#       categories                                            details  \
# 15700         []  {'Package Dimensions': '10.5 x 6.4 x 1.6 inche...
#
#       parent_asin  bought_together
# 15700  B097R46CSY              NaN
