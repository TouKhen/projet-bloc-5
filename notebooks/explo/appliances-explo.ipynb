# %%
from src.data import load_file

df = load_file('../../data/raw/meta_Appliances.jsonl/meta_Appliances.jsonl');

# %%
df.head()
# Out:
#               main_category  \
# 0   Industrial & Scientific
# 1  Tools & Home Improvement
# 2  Tools & Home Improvement
# 3  Tools & Home Improvement
# 4  Tools & Home Improvement
#
#                                                title  average_rating  \
# 0  ROVSUN Ice Maker Machine Countertop, Make 44lb...             3.7
# 1  HANSGO Egg Holder for Refrigerator, Deviled Eg...             4.2
# 2  Clothes Dryer Drum Slide, General Electric, Ho...             3.5
# 3  154567702 Dishwasher Lower Wash Arm Assembly f...             4.5
# 4                        Whirlpool W10918546 Igniter             3.8
#
#    rating_number                                           features  \
# 0             61  [【Quick Ice Making】This countertop ice machine...
# 1             75  [Plastic, Practical Kitchen Storage - Our egg ...
# 2             18                                                 []
# 3             26  [MODEL NUMBER:154567702 Dishwasher Lower Wash ...
# ...

# %% [markdown]
# ### Inspect the shape and columns

# %%
print(df.shape)
print(list(df.columns))
# Out:
# (94327, 16)
# ['main_category', 'title', 'average_rating', 'rating_number', 'features', 'description', 'price', 'images', 'videos', 'store', 'categories', 'details', 'parent_asin', 'bought_together', 'subtitle', 'author']

# %% [markdown]
# ### Check basic info and types

# %%
print(df.info())
print(df.dtypes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94327 entries, 0 to 94326
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   main_category    89651 non-null  object
#  1   title            94327 non-null  object
#  2   average_rating   94327 non-null  float64
#  3   rating_number    94327 non-null  int64
#  4   features         94327 non-null  object
#  5   description      94327 non-null  object
#  6   price            46726 non-null  float64
#  7   images           94327 non-null  object
#  8   videos           94327 non-null  object
#  9   store            93411 non-null  object
#  10  categories       94327 non-null  object
#  11  details          94327 non-null  object
#  12  parent_asin      94327 non-null  object
#  13  bought_together  0 non-null      float64
#  14  subtitle         5 non-null      object
#  15  author           1 non-null      object
# ...

# %% [markdown]
# ### Peek at the data

# %%
df.sample(n=5)
# Out:
#                   main_category  \
# 91007                Appliances
# 4656   Tools & Home Improvement
# 74133  Tools & Home Improvement
# 21387   Industrial & Scientific
# 61848  Tools & Home Improvement
#
#                                                    title  average_rating  \
# 91007  Temperature Control Kit 077B6856, Compatible w...             3.1
# 4656   WPW10545255 Oven Thermal Fuse - Replaces AP602...             4.7
# 74133                        Whirlpool 8193942 Door Seal             3.5
# 21387  TOXOT Ice Maker Portable Ice Maker Countertop ...             5.0
# 61848                                GE WH01X10648 Badge             5.0
#
#        rating_number                                           features  \
# 91007              4  [ADJUSTABLE TEMPERATURE: The temperature repla...
# 4656               5  [➡️ PART NUMBER WPW10545255: It's a high-quali...
# 74133             46                [This is an O.E.M. Authorized part]
# ...

# %% [markdown]
# ### Summary statistics

# %%
df.describe()
# Out:
#        average_rating  rating_number         price  bought_together
# count    94327.000000   94327.000000  46726.000000              0.0
# mean         4.118859     136.367901     86.479954              NaN
# std          0.864040     977.516100    325.318397              NaN
# min          1.000000       1.000000      0.010000              NaN
# 25%          3.800000       3.000000     14.990000              NaN
# 50%          4.300000      13.000000     26.990000              NaN
# 75%          4.700000      53.000000     58.130000              NaN
# max          5.000000   90203.000000  21095.620000              NaN

# %% [markdown]
# ### Missing values

# %%
df.isna().sum()
# Out:
# main_category       4676
# title                  0
# average_rating         0
# rating_number          0
# features               0
# description            0
# price              47601
# images                 0
# videos                 0
# store                916
# categories             0
# details                0
# parent_asin            0
# bought_together    94327
# subtitle           94322
# author             94326
# dtype: int64

# %% [markdown]
# ### Distribution and unique values

# %%
df['average_rating'].value_counts(dropna=False)
# Out:
# average_rating
# 5.0    15600
# 4.5     7554
# 4.6     7059
# 4.4     6621
# 4.3     5978
# 4.7     5519
# 4.0     5320
# 4.2     5063
# 4.1     4413
# 3.9     3259
# 4.8     2996
# 3.8     2784
# 1.0     2766
# 3.7     2371
# 3.0     2192
# 3.6     2038
# 3.5     1957
# 3.4     1507
# 3.3     1298
# 3.2     1115
# 3.1      999
# 4.9      951
# 2.0      834
# 2.9      702
# 2.7      602
# 2.8      571
# 2.5      482
# 2.6      399
# 2.4      264
# 2.3      248
# 1.5      197
# 2.2      177
# 2.1      136
# 1.9       92
# 1.8       72
# 1.7       64
# 1.4       40
# 1.3       39
# 1.6       37
# 1.2       10
# 1.1        1
# Name: count, dtype: int64

# %%
df['store'].value_counts(dropna=False)
# Out:
# store
# Whirlpool     8687
# GE            4994
# FRIGIDAIRE    2912
# SAMSUNG       2245
# LG            1876
#               ...
# FRONHEN          1
# jootic           1
# ying             1
# Atdec            1
# New Brand        1
# Name: count, Length: 13167, dtype: int64
